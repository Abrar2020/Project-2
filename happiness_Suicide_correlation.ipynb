# %%
import pandas as pd
import scipy.stats as stats
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
# load Required libraries

# %%
suicide=pd.read_csv('C:/Users/abrar/Desktop/2019/Data/master.csv')

# %%
suicide.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27820 entries, 0 to 27819
# Data columns (total 12 columns):
# country               27820 non-null object
# year                  27820 non-null int64
# sex                   27820 non-null object
# age                   27820 non-null object
# suicides_no           27820 non-null int64
# population            27820 non-null int64
# suicides/100k pop     27820 non-null float64
# country-year          27820 non-null object
# HDI for year          8364 non-null float64
#  gdp_for_year ($)     27820 non-null object
# gdp_per_capita ($)    27820 non-null int64
# generation            27820 non-null object
# dtypes: float64(2), int64(4), object(6)
# memory usage: 2.5+ MB

# %%
suicide= suicide[['country', 'suicides_no','year']]

# %%
suicide.head()
# Out:
#    country  suicides_no  year
# 0  Albania           21  1987
# 1  Albania           16  1987
# 2  Albania           14  1987
# 3  Albania            1  1987
# 4  Albania            9  1987

# %%
suicide = suicide[suicide["year"].isin(["2016"])]

# %%
suicide.head()
# Out:
#       country  suicides_no  year
# 1248  Armenia           12  2016
# 1249  Armenia           16  2016
# 1250  Armenia           16  2016
# 1251  Armenia            5  2016
# 1252  Armenia            2  2016

# %%
country=suicide.groupby('country')['suicides_no'].sum()

# %%
country.head()
# Out:
# country
# Armenia             67
# Austria           1201
# Croatia            683
# Cyprus              36
# Czech Republic    1318
# Name: suicides_no, dtype: int64

# %%
suicide=suicide.groupby('country')['suicides_no'].sum()

# %%
suicide.head()
# Out:
# country
# Armenia             67
# Austria           1201
# Croatia            683
# Cyprus              36
# Czech Republic    1318
# Name: suicides_no, dtype: int64

# %%
suicide=pd.DataFrame({'country':suicide.keys(),'suicides_no':suicide.values})

# %%
suicide.head()
# Out:
#           country  suicides_no
# 0         Armenia           67
# 1         Austria         1201
# 2         Croatia          683
# 3          Cyprus           36
# 4  Czech Republic         1318

# %%
suicide.columns=['Country', 'suicides_no']

# %%
df_2016=pd.read_csv('C:/Users/abrar/Desktop/2019/Data/2016.csv')

# %%
df_2016.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0      Denmark  Western Europe               1            7.526
# 1  Switzerland  Western Europe               2            7.509
# 2      Iceland  Western Europe               3            7.501
# 3       Norway  Western Europe               4            7.498
# 4      Finland  Western Europe               5            7.413
#
#    Lower Confidence Interval  Upper Confidence Interval  \
# 0                      7.460                      7.592
# 1                      7.428                      7.590
# 2                      7.333                      7.669
# 3                      7.421                      7.575
# 4                      7.351                      7.475
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                   1.44178  1.16374                   0.79504  0.57941
# 1                   1.52733  1.14524                   0.86303  0.58557
# ...

# %%
new=df_2016.merge(suicide,on='Country',how='outer').head()

# %%
new=df_2016.merge(suicide,on='Country',how='outer')

# %%
null_columns = df.columns[df.isnull().any()]
df[null_columns].isnull().sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-c16d64b1058d> in <module>
# ----> 1 null_columns = df.columns[df.isnull().any()]
#       2 df[null_columns].isnull().sum()
#
# NameError: name 'df' is not defined

# %%
happyScore = new["Happiness Score"]

# %%
suicide_rates=new["suicides_no"]

# %%
corr = new.corr()
plt.figure(figsize=(12,12))
sns.heatmap(corr, 
            xticklabels=corr.columns.values,
            yticklabels=corr.columns.values, annot=True, cmap='cubehelix', square=True)
plt.title('Correlation between different features')
corr
# Out:
#                                Happiness Rank  Happiness Score  \
# Happiness Rank                       1.000000        -0.995743
# Happiness Score                     -0.995743         1.000000
# Lower Confidence Interval           -0.994928         0.999485
# Upper Confidence Interval           -0.995525         0.999474
# Economy (GDP per Capita)            -0.793577         0.790322
# Family                              -0.733276         0.739252
# Health (Life Expectancy)            -0.767991         0.765384
# Freedom                             -0.557169         0.566827
# Trust (Government Corruption)       -0.387102         0.402032
# Generosity                          -0.145369         0.156848
# Dystopia Residual                   -0.542616         0.543738
# suicides_no                         -0.247294         0.229624
#
#                                Lower Confidence Interval  \
# Happiness Rank                                 -0.994928
# ...

# %%
null_columns = new.columns[new.isnull().any()]
new[null_columns].isnull().sum()
# Out:
# Region                             1
# Happiness Rank                     1
# Happiness Score                    1
# Lower Confidence Interval          1
# Upper Confidence Interval          1
# Economy (GDP per Capita)           1
# Family                             1
# Health (Life Expectancy)           1
# Freedom                            1
# Trust (Government Corruption)      1
# Generosity                         1
# Dystopia Residual                  1
# suicides_no                      142
# dtype: int64

# %%
 new=new.dropna()

# %%
corr = new.corr()
plt.figure(figsize=(12,12))
sns.heatmap(corr, 
            xticklabels=corr.columns.values,
            yticklabels=corr.columns.values, annot=True, cmap='cubehelix', square=True)
plt.title('Correlation between different features')
corr
# Out:
#                                Happiness Rank  Happiness Score  \
# Happiness Rank                       1.000000        -0.995074
# Happiness Score                     -0.995074         1.000000
# Lower Confidence Interval           -0.993317         0.999146
# Upper Confidence Interval           -0.995136         0.999154
# Economy (GDP per Capita)            -0.714145         0.696905
# Family                              -0.633623         0.663029
# Health (Life Expectancy)            -0.728227         0.738486
# Freedom                             -0.843572         0.844292
# Trust (Government Corruption)       -0.596440         0.610079
# Generosity                          -0.572457         0.588315
# Dystopia Residual                   -0.656602         0.650563
# suicides_no                         -0.247294         0.229624
#
#                                Lower Confidence Interval  \
# Happiness Rank                                 -0.993317
# ...

# %%
null_columns = new.columns[new.isnull().any()]
new[null_columns].isnull().sum()
# Out:
# Series([], dtype: float64)

# %%
new=df_2016.merge(suicide,on='Country',how='outer')

# %%
corr = new.corr()
